# %% [markdown]
# # NVIDIA DeepLearningExamples Evaluation (Phase 2)
#
# This notebook tests `loadtune`'s ability to autonomously optimize heavy PyTorch workloads mimicking the complex augmentation pipelines and NLP bottlenecks seen in the official NVIDIA DeepLearningExamples.
#
# **Instructions:**
# 1. Go to **Runtime > Change runtime type** and ensure a **T4 GPU** (or better) is selected.
# 2. Run the cells below.

# %%
# 1. Clone the repository
# !git clone https://github.com/marijaEf/loadtune.git

# 2. Install loadtune and all test dependencies (including transformers/torchvision)
# !cd loadtune && pip install -e ".[all]"

# %%
# 3. Run the GPU Evaluation Test Suite!
# This will invoke loadtune to profile the mock ResNet50 and BERT workloads,
# automatically proposing configurations and verifying that the final throughput 
# is optimized.
# !cd loadtune && pytest tests/test_gpu_evaluation.py -v -s
